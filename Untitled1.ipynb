# %%
# Standard library imports
import os
import time
import warnings
import sys
import requests


# Third party imports
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
from scipy.stats import zscore
from sklearn.metrics import r2_score, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt
from cryptocmd import CmcScraper
from datetime import datetime, timedelta
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.model_selection import train_test_split
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Models
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.layers import TimeDistributed, Conv1D, MaxPooling1D, Flatten
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score



# Local application imports
# Import other necessary libraries and modules here
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, Span, Range1d
from bokeh.layouts import column
from bokeh.models.widgets import Button
from bokeh.models.callbacks import CustomJS
from bokeh.themes import Theme
from math import pi
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.models import HoverTool
from bokeh.models import ColumnDataSource, WheelZoomTool
import pandas as pd


warnings.filterwarnings('ignore')

# %%
# Block 1 - load data with CmC Scrapper
class CryptoData:
    """
    This class is responsible for fetching and formatting cryptocurrency data.

    Input:
        crypto_symbol (str): The symbol of the cryptocurrency, e.g., "BTC" for Bitcoin.

    Methods:
        get_cryptocmd_data: Fetches cryptocurrency data and returns a formatted DataFrame.
        get_display_data: Fetches and formats cryptocurrency data for display purposes.
    """
    def __init__(self, crypto_symbol: str):
        self.crypto_symbol = crypto_symbol

    def _fetch_cryptocmd_data(self) -> pd.DataFrame:
        try:
            scraper = CmcScraper(self.crypto_symbol)
            return scraper.get_dataframe()
        except Exception as e:
            print(f'An error occurred while fetching data: {e}')
            return pd.DataFrame()  # Return an empty DataFrame when an error occurs

    def get_cryptocmd_data(self) -> pd.DataFrame:
        df = self._fetch_cryptocmd_data()
        df.set_index('Date', inplace=True)
        df.index = pd.to_datetime(df.index)
        return df.round(2)

    @staticmethod
    def _format_monetary_value(value: float) -> str:
        return "${:,.2f}".format(value)

    @staticmethod
    def _format_volume_value(value: float) -> str:
        return "{:,.2f}".format(value)

    def get_display_data(self) -> pd.DataFrame:
        display_df = self.get_cryptocmd_data().copy()
        monetary_columns = ['Open', 'High', 'Low', 'Close', 'Market Cap']
        display_df[monetary_columns] = display_df[monetary_columns].applymap(self._format_monetary_value)
        display_df['Volume'] = display_df['Volume'].apply(self._format_volume_value)
        return display_df

# %%
crypto = CryptoData("BTC")
data = crypto.get_cryptocmd_data()
display_data = crypto.get_display_data()
display_data
# Out:
#                   Open        High         Low       Close             Volume  \
# Date
# 2023-06-22  $29,995.94  $30,496.00  $29,679.16  $29,912.28  20,653,160,490.91
# 2023-06-21  $28,311.31  $30,737.33  $28,283.41  $30,027.30  33,346,760,979.13
# 2023-06-20  $26,841.66  $28,388.97  $26,668.79  $28,327.49  22,211,859,146.73
# 2023-06-19  $26,335.44  $26,984.61  $26,312.83  $26,851.03  12,826,986,222.15
# 2023-06-18  $26,510.46  $26,675.93  $26,325.89  $26,336.21   9,565,695,128.64
# ...                ...         ...         ...         ...                ...
# 2013-05-02     $116.38     $125.60      $92.28     $105.21               0.00
# 2013-05-01     $139.00     $139.89     $107.72     $116.99               0.00
# 2013-04-30     $144.00     $146.93     $134.05     $139.00               0.00
# 2013-04-29     $134.44     $147.49     $134.00     $144.54               0.00
# 2013-04-28     $135.30     $135.98     $132.10     $134.21               0.00
#
#                      Market Cap
# Date
# 2023-06-22  $580,578,124,574.23
# 2023-06-21  $582,785,323,709.11
# 2023-06-20  $549,771,733,917.47
# 2023-06-19  $521,094,554,604.37
# 2023-06-18  $511,079,706,782.86
# ...                         ...
# 2013-05-02    $1,168,517,495.25
# 2013-05-01    $1,298,954,593.75
# 2013-04-30    $1,542,813,125.00
# 2013-04-29    $1,603,768,864.50
# 2013-04-28    $1,488,566,728.25
#
# [3708 rows x 6 columns]

# %%
class DataPreprocessing:

    def __init__(self, data, targets=[], columns_to_scale=[], random_state=None):
        self.data = data.sort_index(ascending=True)
        self.targets = targets
        self.columns_to_scale = columns_to_scale
        self.random_state = random_state
        self.data_scaled = None  # Initialize the data_scaled attribute

    def missing_values_table(self):
        mis_val = self.data.isnull().sum()
        mis_val_percent = 100 * mis_val / len(self.data)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
            columns={0: 'Missing Values', 1: '% of Total Values'}
        )
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:, 1] != 0
        ].sort_values('% of Total Values', ascending=False).round(1)

        print(
            f"Your selected dataframe has {self.data.shape[1]} columns.\n"
            f"There are {mis_val_table_ren_columns.shape[0]} columns that have missing values."
        )

        return mis_val_table_ren_columns

    def normalize_and_scale(self):
        data_normalized = self.data.copy()
        self.scaler = StandardScaler()
        # Instantiate a separate StandardScaler for the 'Close' prices
        self.close_scaler = StandardScaler()
        data_normalized[self.columns_to_scale] = self.scaler.fit_transform(data_normalized[self.columns_to_scale])
        # Fit the close_scaler on the 'Close' prices
        self.close_scaler.fit(data_normalized[['Close']])
        self.data_scaled = data_normalized
        return self.data_scaled


    def split_data(self, splitter):
        # Ensure that data_normalized has been calculated
        if self.data_scaled is None:
            raise ValueError("Please call 'normalize_and_scale' method before splitting the data.")

        # Calculate the index position to split the data
        split_index = int(len(self.data_scaled) * (1 - splitter))

        # Split the data into train and test sets
        data_train = self.data_scaled.iloc[:split_index]
        data_test = self.data_scaled.iloc[split_index:]

        X_train = data_train.loc[:, data_train.columns != 'Close']
        y_train = data_train.loc[:, 'Close']

        X_test = data_test.loc[:, data_test.columns != 'Close']
        y_test = data_test.loc[:, 'Close']

        # Convert to NumPy array
        y_train= y_train.to_numpy()
        y_test= y_test.to_numpy()
        X_train= X_train.to_numpy()
        X_test= X_test.to_numpy()

        # Reshape to 3D [samples, timesteps, features]
        X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
        X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

        return X_train, y_train, X_test, y_test

    def visualize_split(self, train_close, test_close):
        # Restore target values before normalization
        y_train_restored = self.data['Close'][:len(y_train)]
        y_test_restored = self.data['Close'][len(y_train):]

        train_dates = self.data.index[:len(train_close)]
        test_dates = self.data.index[-len(test_close):]

        # Set up Bokeh figure
        p = figure(width=950, height=500, x_axis_type="datetime", title="Training and Testing Data")

        # Add gridlines to the plot
        p.xgrid.grid_line_color = "gray"
        p.ygrid.grid_line_color = "gray"
        p.xgrid.grid_line_alpha = 0.3
        p.ygrid.grid_line_alpha = 0.3

        # Training Data Line
        p.line(train_dates, y_train_restored, color='blue', legend_label='Training Data', line_width=2)

        # Testing Data Line
        p.line(test_dates, y_test_restored, color='orange', legend_label='Testing Data', line_width=2)

        # Add hover tool
        hover = HoverTool(tooltips=[("Date", "@x{%F}"), ("Value", "$@y{0,0.00}")],
                  formatters={"@x": "datetime"})

        p.add_tools(hover)
        p.toolbar.logo = None
        # Show the dynamic line chart
        show(p)

# %%
columns_to_scale = ['Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap']
preprocessor = DataPreprocessing(data, columns_to_scale=columns_to_scale)
data_normalized = preprocessor.normalize_and_scale()

# %%
# Split the data into train and test sets
X_train, y_train, X_test, y_test = preprocessor.split_data(splitter=0.2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (2966, 1, 5) (2966,) (742, 1, 5) (742,)

# %%
preprocessor.visualize_split(y_train, y_test)

# %%
class LSTM_Models:
    def __init__(self, X_train, y_train, X_test, y_test, model):
        self.X_train = X_train
        self.y_train = y_train
        self.X_test = X_test
        self.y_test = y_test
        self.model = model

    def train_model(self, epochs=100, batch_size=50):
        self.history = self.model.fit(self.X_train, self.y_train, epochs=epochs, batch_size=batch_size, verbose=2,validation_data=(self.X_test, self.y_test), shuffle=False)

    def make_predictions(self, close_scaler):
        # Make predictions on the normalized data
        train_predict = self.model.predict(self.X_train)
        test_predict = self.model.predict(self.X_test)
        # Invert predictions to get them on the same scale as the original data
        train_predict = close_scaler.inverse_transform(train_predict)
        y_train_rescaled = close_scaler.inverse_transform([self.y_train])
        test_predict = close_scaler.inverse_transform(test_predict)
        y_test_rescaled = close_scaler.inverse_transform([self.y_test])
        # Create a DataFrame to compare actual vs predicted values for the training data
        train_comparison_df = pd.DataFrame({
            'Actual': y_train_rescaled[0],
            'Predict': train_predict[:,0]
        })
        # Create a DataFrame to compare actual vs predicted values for the testing data
        test_comparison_df = pd.DataFrame({
            'Actual': y_test_rescaled[0],
            'Predict': test_predict[:,0]
        })

        return train_comparison_df, test_comparison_df

    def plot_history(self):
        plt.figure(figsize=(14, 7))
        # Plot the loss
        plt.plot(self.history.history['loss'], label='Loss')
        plt.plot(self.history.history['val_loss'], label='Validation Loss')
        # Add title and labels
        plt.title('Model Loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend()
        # Show the plot
        plt.show()

        from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


    def evaluate_model(self, train_comparison_df, test_comparison_df):
        # Calculate metrics for the training data
        train_rmse = mean_squared_error(train_comparison_df['Actual'], train_comparison_df['Predict'], squared=False)
        train_mae = mean_absolute_error(train_comparison_df['Actual'], train_comparison_df['Predict'])
        train_mse = mean_squared_error(train_comparison_df['Actual'], train_comparison_df['Predict'])
        train_r2 = r2_score(train_comparison_df['Actual'], train_comparison_df['Predict'])
        # Calculate metrics for the testing data
        test_rmse = mean_squared_error(test_comparison_df['Actual'], test_comparison_df['Predict'], squared=False)
        test_mae = mean_absolute_error(test_comparison_df['Actual'], test_comparison_df['Predict'])
        test_mse = mean_squared_error(test_comparison_df['Actual'], test_comparison_df['Predict'])
        test_r2 = r2_score(test_comparison_df['Actual'], test_comparison_df['Predict'])
        # Create a DataFrame to hold the results
        results_df = pd.DataFrame({
            'Metric': ['RMSE', 'MAE', 'MSE', 'R2'],
            'Train': [train_rmse, train_mae, train_mse, train_r2],
            'Test': [test_rmse, test_mae, test_mse, test_r2]
        })

        return results_df

    def plot_predictions(self, train_comparison_df, test_comparison_df):
        plt.figure(figsize=(14, 7))
        # Plot the actual and predicted values for the training data
        plt.subplot(1, 2, 1)
        plt.plot(train_comparison_df['Actual'], label='Actual')
        plt.plot(train_comparison_df['Predict'], label='Predict')
        plt.title('Training Data: Actual vs Predicted')
        plt.legend()
        # Plot the actual and predicted values for the testing data
        plt.subplot(1, 2, 2)
        plt.plot(test_comparison_df['Actual'], label='Actual')
        plt.plot(test_comparison_df['Predict'], label='Predict')
        plt.title('Testing Data: Actual vs Predicted')
        plt.legend()
        # Show the plot
        plt.show()


model1 = Sequential()
model1.add(LSTM(120, activation="tanh", input_shape=(1, 5)))
model1.add(Dropout(0.15))
model1.add(Dense(1))
model1.compile(loss='mean_squared_error', optimizer='adam')
model1.summary()

# Define model 2
model2 = Sequential()
model2.add(LSTM(120, activation="tanh", input_shape=(1, 5)))
model2.add(Dropout(0.15))
model2.add(Dense(50))
model2.compile(loss='mean_squared_error', optimizer='adam')
model2.summary()

# Define model 3
model3 = Sequential()
model3.add(LSTM(256, activation="tanh", input_shape=(1, 5)))
model3.add(Dropout(0.15))
model3.add(Dense(1))
model3.compile(loss='mean_squared_error', optimizer='adam')
model3.summary()


# Define model 4
model4 = Sequential()
model4.add(LSTM(256, activation="tanh", input_shape=(1, 5)))
model4.add(Dropout(0.15))
model4.add(Dense(50))
model4.compile(loss='mean_squared_error', optimizer='adam')
model4.summary()


# Define model 5
model5 = Sequential()
model5.add(LSTM(120, activation="tanh", input_shape=(1, 5)))
model5.add(Dropout(0.2))
model5.add(Dense(250))
model5.compile(loss='mean_squared_error', optimizer='adam')


# Define model 6
model6 = Sequential()
model6.add(LSTM(120, activation="tanh", input_shape=(1, 5)))
model6.add(Dropout(0.2))
model6.add(Dense(2000))
model6.compile(loss='mean_squared_error', optimizer='adam')

# Define model 6
model7 = Sequential()
model7.add(LSTM(120, activation="tanh", input_shape=(1, 5)))
model7.add(Dropout(0.2))
model7.add(Dense(4.5))
model7.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# Model: "sequential_88"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_93 (LSTM)              (None, 120)               60480
#
#  dropout_83 (Dropout)        (None, 120)               0
#
#  dense_83 (Dense)            (None, 1)                 121
#
# =================================================================
# Total params: 60,601
# Trainable params: 60,601
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_89"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_94 (LSTM)              (None, 120)               60480
#
#  dropout_84 (Dropout)        (None, 120)               0
#
#  dense_84 (Dense)            (None, 50)                6050
#
# =================================================================
# Total params: 66,530
# Trainable params: 66,530
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_90"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_95 (LSTM)              (None, 256)               268288
#
#  dropout_85 (Dropout)        (None, 256)               0
#
#  dense_85 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 268,545
# Trainable params: 268,545
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_91"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_96 (LSTM)              (None, 256)               268288
#
#  dropout_86 (Dropout)        (None, 256)               0
#
#  dense_86 (Dense)            (None, 50)                12850
#
# =================================================================
# Total params: 281,138
# Trainable params: 281,138
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Initialize and train the LSTM model 1
lstm_1 = LSTM_Models(X_train, y_train, X_test, y_test, model1)
lstm_1.train_model(epochs=100, batch_size=50)
train_comparison_df,test_comparison_df = lstm_1.make_predictions(preprocessor.close_scaler)
lstm_1.plot_predictions(train_comparison_df, test_comparison_df)
results_df1 = lstm_1.evaluate_model(train_comparison_df, test_comparison_df)
print(results_df1)
# Out:
# (2966, 1, 5) (2966,) (742, 1, 5) (742,)
# Epoch 1/100
# 60/60 - 3s - loss: 0.2601 - val_loss: 0.8850 - 3s/epoch - 44ms/step
# Epoch 2/100
# 60/60 - 1s - loss: 0.0581 - val_loss: 0.3050 - 838ms/epoch - 14ms/step
# Epoch 3/100
# 60/60 - 1s - loss: 0.0177 - val_loss: 0.0677 - 816ms/epoch - 14ms/step
# Epoch 4/100
# 60/60 - 1s - loss: 0.0087 - val_loss: 0.0261 - 1000ms/epoch - 17ms/step
# Epoch 5/100
# 60/60 - 1s - loss: 0.0047 - val_loss: 0.0165 - 923ms/epoch - 15ms/step
# Epoch 6/100
# 60/60 - 1s - loss: 0.0031 - val_loss: 0.0095 - 872ms/epoch - 15ms/step
# Epoch 7/100
# 60/60 - 1s - loss: 0.0029 - val_loss: 0.0073 - 903ms/epoch - 15ms/step
# Epoch 8/100
# 60/60 - 1s - loss: 0.0026 - val_loss: 0.0060 - 893ms/epoch - 15ms/step
# Epoch 9/100
# 60/60 - 1s - loss: 0.0029 - val_loss: 0.0055 - 827ms/epoch - 14ms/step
# Epoch 10/100
# 60/60 - 1s - loss: 0.0026 - val_loss: 0.0052 - 806ms/epoch - 13ms/step
# Epoch 11/100
# 60/60 - 1s - loss: 0.0031 - val_loss: 0.0053 - 827ms/epoch - 14ms/step
# Epoch 12/100
# 60/60 - 1s - loss: 0.0025 - val_loss: 0.0050 - 818ms/epoch - 14ms/step
# Epoch 13/100
# 60/60 - 1s - loss: 0.0034 - val_loss: 0.0055 - 811ms/epoch - 14ms/step
# Epoch 14/100
# 60/60 - 1s - loss: 0.0043 - val_loss: 0.0046 - 817ms/epoch - 14ms/step
# Epoch 15/100
# 60/60 - 1s - loss: 0.0131 - val_loss: 0.0099 - 856ms/epoch - 14ms/step
# Epoch 16/100
# 60/60 - 1s - loss: 0.0270 - val_loss: 0.0094 - 831ms/epoch - 14ms/step
# Epoch 17/100
# 60/60 - 1s - loss: 0.0733 - val_loss: 0.1592 - 809ms/epoch - 13ms/step
# Epoch 18/100
# 60/60 - 1s - loss: 0.0255 - val_loss: 0.0373 - 818ms/epoch - 14ms/step
# Epoch 19/100
# 60/60 - 1s - loss: 0.0275 - val_loss: 0.0594 - 816ms/epoch - 14ms/step
# Epoch 20/100
# 60/60 - 1s - loss: 0.0096 - val_loss: 0.0250 - 875ms/epoch - 15ms/step
# Epoch 21/100
# 60/60 - 1s - loss: 0.0084 - val_loss: 0.0158 - 925ms/epoch - 15ms/step
# Epoch 22/100
# 60/60 - 1s - loss: 0.0048 - val_loss: 0.0169 - 918ms/epoch - 15ms/step
# Epoch 23/100
# 60/60 - 1s - loss: 0.0059 - val_loss: 0.0109 - 894ms/epoch - 15ms/step
# Epoch 24/100
# 60/60 - 1s - loss: 0.0037 - val_loss: 0.0146 - 858ms/epoch - 14ms/step
# Epoch 25/100
# 60/60 - 1s - loss: 0.0068 - val_loss: 0.0094 - 897ms/epoch - 15ms/step
# Epoch 26/100
# 60/60 - 1s - loss: 0.0050 - val_loss: 0.0139 - 887ms/epoch - 15ms/step
# Epoch 27/100
# 60/60 - 1s - loss: 0.0098 - val_loss: 0.0117 - 795ms/epoch - 13ms/step
# Epoch 28/100
# 60/60 - 1s - loss: 0.0082 - val_loss: 0.0165 - 807ms/epoch - 13ms/step
# Epoch 29/100
# 60/60 - 1s - loss: 0.0151 - val_loss: 0.0208 - 797ms/epoch - 13ms/step
# Epoch 30/100
# 60/60 - 1s - loss: 0.0116 - val_loss: 0.0222 - 828ms/epoch - 14ms/step
# Epoch 31/100
# 60/60 - 1s - loss: 0.0201 - val_loss: 0.0310 - 800ms/epoch - 13ms/step
# Epoch 32/100
# 60/60 - 1s - loss: 0.0120 - val_loss: 0.0269 - 809ms/epoch - 13ms/step
# Epoch 33/100
# 60/60 - 1s - loss: 0.0172 - val_loss: 0.0251 - 802ms/epoch - 13ms/step
# Epoch 34/100
# 60/60 - 1s - loss: 0.0095 - val_loss: 0.0284 - 805ms/epoch - 13ms/step
# Epoch 35/100
# 60/60 - 1s - loss: 0.0132 - val_loss: 0.0187 - 807ms/epoch - 13ms/step
# Epoch 36/100
# 60/60 - 1s - loss: 0.0075 - val_loss: 0.0276 - 820ms/epoch - 14ms/step
# Epoch 37/100
# 60/60 - 1s - loss: 0.0103 - val_loss: 0.0136 - 794ms/epoch - 13ms/step
# Epoch 38/100
# 60/60 - 1s - loss: 0.0062 - val_loss: 0.0257 - 809ms/epoch - 13ms/step
# Epoch 39/100
# 60/60 - 1s - loss: 0.0085 - val_loss: 0.0111 - 791ms/epoch - 13ms/step
# Epoch 40/100
# 60/60 - 1s - loss: 0.0063 - val_loss: 0.0195 - 890ms/epoch - 15ms/step
# Epoch 41/100
# 60/60 - 1s - loss: 0.0126 - val_loss: 0.0152 - 888ms/epoch - 15ms/step
# Epoch 42/100
# 60/60 - 1s - loss: 0.0090 - val_loss: 0.0271 - 947ms/epoch - 16ms/step
# Epoch 43/100
# 60/60 - 1s - loss: 0.0150 - val_loss: 0.0183 - 900ms/epoch - 15ms/step
# Epoch 44/100
# 60/60 - 1s - loss: 0.0103 - val_loss: 0.0305 - 904ms/epoch - 15ms/step
# Epoch 45/100
# 60/60 - 1s - loss: 0.0182 - val_loss: 0.0215 - 837ms/epoch - 14ms/step
# Epoch 46/100
# 60/60 - 1s - loss: 0.0100 - val_loss: 0.0345 - 828ms/epoch - 14ms/step
# Epoch 47/100
# 60/60 - 1s - loss: 0.0154 - val_loss: 0.0189 - 828ms/epoch - 14ms/step
# Epoch 48/100
# 60/60 - 1s - loss: 0.0088 - val_loss: 0.0310 - 788ms/epoch - 13ms/step
# Epoch 49/100
# 60/60 - 1s - loss: 0.0124 - val_loss: 0.0158 - 822ms/epoch - 14ms/step
# Epoch 50/100
# 60/60 - 1s - loss: 0.0069 - val_loss: 0.0299 - 820ms/epoch - 14ms/step
# Epoch 51/100
# 60/60 - 1s - loss: 0.0099 - val_loss: 0.0117 - 808ms/epoch - 13ms/step
# Epoch 52/100
# 60/60 - 1s - loss: 0.0065 - val_loss: 0.0272 - 822ms/epoch - 14ms/step
# Epoch 53/100
# 60/60 - 1s - loss: 0.0110 - val_loss: 0.0128 - 815ms/epoch - 14ms/step
# Epoch 54/100
# 60/60 - 1s - loss: 0.0071 - val_loss: 0.0319 - 829ms/epoch - 14ms/step
# Epoch 55/100
# 60/60 - 1s - loss: 0.0123 - val_loss: 0.0125 - 809ms/epoch - 13ms/step
# Epoch 56/100
# 60/60 - 1s - loss: 0.0083 - val_loss: 0.0341 - 814ms/epoch - 14ms/step
# Epoch 57/100
# 60/60 - 1s - loss: 0.0118 - val_loss: 0.0137 - 819ms/epoch - 14ms/step
# Epoch 58/100
# 60/60 - 1s - loss: 0.0077 - val_loss: 0.0317 - 903ms/epoch - 15ms/step
# Epoch 59/100
# 60/60 - 1s - loss: 0.0134 - val_loss: 0.0137 - 894ms/epoch - 15ms/step
# Epoch 60/100
# 60/60 - 1s - loss: 0.0089 - val_loss: 0.0343 - 888ms/epoch - 15ms/step
# Epoch 61/100
# 60/60 - 1s - loss: 0.0145 - val_loss: 0.0175 - 893ms/epoch - 15ms/step
# Epoch 62/100
# 60/60 - 1s - loss: 0.0088 - val_loss: 0.0305 - 890ms/epoch - 15ms/step
# Epoch 63/100
# 60/60 - 1s - loss: 0.0150 - val_loss: 0.0176 - 798ms/epoch - 13ms/step
# Epoch 64/100
# 60/60 - 1s - loss: 0.0085 - val_loss: 0.0379 - 815ms/epoch - 14ms/step
# Epoch 65/100
# 60/60 - 1s - loss: 0.0131 - val_loss: 0.0154 - 799ms/epoch - 13ms/step
# Epoch 66/100
# 60/60 - 1s - loss: 0.0079 - val_loss: 0.0334 - 826ms/epoch - 14ms/step
# Epoch 67/100
# 60/60 - 1s - loss: 0.0121 - val_loss: 0.0149 - 828ms/epoch - 14ms/step
# Epoch 68/100
# 60/60 - 1s - loss: 0.0070 - val_loss: 0.0346 - 813ms/epoch - 14ms/step
# Epoch 69/100
# 60/60 - 1s - loss: 0.0108 - val_loss: 0.0131 - 810ms/epoch - 14ms/step
# Epoch 70/100
# 60/60 - 1s - loss: 0.0059 - val_loss: 0.0348 - 805ms/epoch - 13ms/step
# Epoch 71/100
# 60/60 - 1s - loss: 0.0089 - val_loss: 0.0113 - 839ms/epoch - 14ms/step
# Epoch 72/100
# 60/60 - 1s - loss: 0.0064 - val_loss: 0.0285 - 832ms/epoch - 14ms/step
# Epoch 73/100
# 60/60 - 1s - loss: 0.0103 - val_loss: 0.0115 - 818ms/epoch - 14ms/step
# Epoch 74/100
# 60/60 - 1s - loss: 0.0074 - val_loss: 0.0344 - 801ms/epoch - 13ms/step
# Epoch 75/100
# 60/60 - 1s - loss: 0.0122 - val_loss: 0.0133 - 807ms/epoch - 13ms/step
# Epoch 76/100
# 60/60 - 1s - loss: 0.0080 - val_loss: 0.0362 - 901ms/epoch - 15ms/step
# Epoch 77/100
# 60/60 - 1s - loss: 0.0126 - val_loss: 0.0145 - 919ms/epoch - 15ms/step
# Epoch 78/100
# 60/60 - 1s - loss: 0.0078 - val_loss: 0.0380 - 877ms/epoch - 15ms/step
# Epoch 79/100
# 60/60 - 1s - loss: 0.0125 - val_loss: 0.0145 - 894ms/epoch - 15ms/step
# Epoch 80/100
# 60/60 - 1s - loss: 0.0076 - val_loss: 0.0380 - 896ms/epoch - 15ms/step
# Epoch 81/100
# 60/60 - 1s - loss: 0.0113 - val_loss: 0.0139 - 815ms/epoch - 14ms/step
# Epoch 82/100
# 60/60 - 1s - loss: 0.0068 - val_loss: 0.0348 - 813ms/epoch - 14ms/step
# Epoch 83/100
# 60/60 - 1s - loss: 0.0116 - val_loss: 0.0133 - 831ms/epoch - 14ms/step
# Epoch 84/100
# 60/60 - 1s - loss: 0.0079 - val_loss: 0.0375 - 808ms/epoch - 13ms/step
# Epoch 85/100
# 60/60 - 1s - loss: 0.0129 - val_loss: 0.0143 - 813ms/epoch - 14ms/step
# Epoch 86/100
# 60/60 - 1s - loss: 0.0077 - val_loss: 0.0420 - 813ms/epoch - 14ms/step
# Epoch 87/100
# 60/60 - 1s - loss: 0.0115 - val_loss: 0.0124 - 814ms/epoch - 14ms/step
# Epoch 88/100
# 60/60 - 1s - loss: 0.0072 - val_loss: 0.0418 - 825ms/epoch - 14ms/step
# Epoch 89/100
# 60/60 - 1s - loss: 0.0113 - val_loss: 0.0130 - 810ms/epoch - 14ms/step
# Epoch 90/100
# 60/60 - 1s - loss: 0.0074 - val_loss: 0.0369 - 808ms/epoch - 13ms/step
# Epoch 91/100
# 60/60 - 1s - loss: 0.0130 - val_loss: 0.0141 - 802ms/epoch - 13ms/step
# Epoch 92/100
# 60/60 - 1s - loss: 0.0074 - val_loss: 0.0413 - 815ms/epoch - 14ms/step
# Epoch 93/100
# 60/60 - 1s - loss: 0.0116 - val_loss: 0.0123 - 825ms/epoch - 14ms/step
# Epoch 94/100
# 60/60 - 1s - loss: 0.0081 - val_loss: 0.0398 - 867ms/epoch - 14ms/step
# Epoch 95/100
# 60/60 - 1s - loss: 0.0138 - val_loss: 0.0140 - 892ms/epoch - 15ms/step
# Epoch 96/100
# 60/60 - 1s - loss: 0.0086 - val_loss: 0.0448 - 936ms/epoch - 16ms/step
# Epoch 97/100
# 60/60 - 1s - loss: 0.0132 - val_loss: 0.0143 - 960ms/epoch - 16ms/step
# Epoch 98/100
# 60/60 - 1s - loss: 0.0080 - val_loss: 0.0415 - 970ms/epoch - 16ms/step
# Epoch 99/100
# 60/60 - 1s - loss: 0.0121 - val_loss: 0.0146 - 897ms/epoch - 15ms/step
# Epoch 100/100
# 60/60 - 1s - loss: 0.0067 - val_loss: 0.0393 - 842ms/epoch - 14ms/step
# 93/93 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 0s 3ms/step
#   Metric     Train      Test
# 0   RMSE  0.048482  0.198211
# 1    MAE  0.034710  0.179798
# 2    MSE  0.002351  0.039287
# 3     R2  0.995326  0.942172

# %%
# Initialize and train the LSTM model 2
lstm_2 = LSTM_Models(X_train, y_train, X_test, y_test, model2)
lstm_2.train_model(epochs=100, batch_size=50)
train_comparison_df,test_comparison_df = lstm_2.make_predictions(preprocessor.close_scaler)
lstm_2.plot_predictions(train_comparison_df, test_comparison_df)
results_df2 = lstm_2.evaluate_model(train_comparison_df, test_comparison_df)
print(results_df2)
# Out:
# Epoch 1/100
# 60/60 - 3s - loss: 0.4415 - val_loss: 1.6159 - 3s/epoch - 50ms/step
# Epoch 2/100
# 60/60 - 1s - loss: 0.1351 - val_loss: 0.7995 - 903ms/epoch - 15ms/step
# Epoch 3/100
# 60/60 - 1s - loss: 0.0615 - val_loss: 0.3289 - 917ms/epoch - 15ms/step
# Epoch 4/100
# 60/60 - 1s - loss: 0.0251 - val_loss: 0.1014 - 937ms/epoch - 16ms/step
# Epoch 5/100
# 60/60 - 1s - loss: 0.0136 - val_loss: 0.0470 - 860ms/epoch - 14ms/step
# Epoch 6/100
# 60/60 - 1s - loss: 0.0093 - val_loss: 0.0319 - 856ms/epoch - 14ms/step
# Epoch 7/100
# 60/60 - 1s - loss: 0.0064 - val_loss: 0.0201 - 928ms/epoch - 15ms/step
# Epoch 8/100
# 60/60 - 1s - loss: 0.0056 - val_loss: 0.0153 - 919ms/epoch - 15ms/step
# Epoch 9/100
# 60/60 - 1s - loss: 0.0051 - val_loss: 0.0123 - 941ms/epoch - 16ms/step
# Epoch 10/100
# 60/60 - 1s - loss: 0.0053 - val_loss: 0.0111 - 943ms/epoch - 16ms/step
# Epoch 11/100
# 60/60 - 1s - loss: 0.0047 - val_loss: 0.0100 - 951ms/epoch - 16ms/step
# Epoch 12/100
# 60/60 - 1s - loss: 0.0048 - val_loss: 0.0101 - 897ms/epoch - 15ms/step
# Epoch 13/100
# 60/60 - 1s - loss: 0.0047 - val_loss: 0.0100 - 882ms/epoch - 15ms/step
# Epoch 14/100
# 60/60 - 1s - loss: 0.0043 - val_loss: 0.0098 - 882ms/epoch - 15ms/step
# Epoch 15/100
# 60/60 - 1s - loss: 0.0045 - val_loss: 0.0100 - 896ms/epoch - 15ms/step
# Epoch 16/100
# 60/60 - 1s - loss: 0.0042 - val_loss: 0.0101 - 865ms/epoch - 14ms/step
# Epoch 17/100
# 60/60 - 1s - loss: 0.0044 - val_loss: 0.0100 - 878ms/epoch - 15ms/step
# Epoch 18/100
# 60/60 - 1s - loss: 0.0040 - val_loss: 0.0095 - 857ms/epoch - 14ms/step
# Epoch 19/100
# 60/60 - 1s - loss: 0.0065 - val_loss: 0.0102 - 870ms/epoch - 15ms/step
# Epoch 20/100
# 60/60 - 1s - loss: 0.0082 - val_loss: 0.0087 - 898ms/epoch - 15ms/step
# Epoch 21/100
# 60/60 - 1s - loss: 0.0282 - val_loss: 0.0252 - 876ms/epoch - 15ms/step
# Epoch 22/100
# 60/60 - 1s - loss: 0.0350 - val_loss: 0.0287 - 867ms/epoch - 14ms/step
# Epoch 23/100
# 60/60 - 1s - loss: 0.0677 - val_loss: 0.1575 - 875ms/epoch - 15ms/step
# Epoch 24/100
# 60/60 - 1s - loss: 0.0139 - val_loss: 0.0308 - 925ms/epoch - 15ms/step
# Epoch 25/100
# 60/60 - 1s - loss: 0.0139 - val_loss: 0.0216 - 920ms/epoch - 15ms/step
# Epoch 26/100
# 60/60 - 1s - loss: 0.0067 - val_loss: 0.0257 - 933ms/epoch - 16ms/step
# Epoch 27/100
# 60/60 - 1s - loss: 0.0082 - val_loss: 0.0147 - 944ms/epoch - 16ms/step
# Epoch 28/100
# 60/60 - 1s - loss: 0.0048 - val_loss: 0.0205 - 934ms/epoch - 16ms/step
# Epoch 29/100
# 60/60 - 1s - loss: 0.0067 - val_loss: 0.0131 - 891ms/epoch - 15ms/step
# Epoch 30/100
# 60/60 - 1s - loss: 0.0048 - val_loss: 0.0208 - 885ms/epoch - 15ms/step
# Epoch 31/100
# 60/60 - 1s - loss: 0.0076 - val_loss: 0.0124 - 870ms/epoch - 15ms/step
# Epoch 32/100
# 60/60 - 1s - loss: 0.0055 - val_loss: 0.0202 - 883ms/epoch - 15ms/step
# Epoch 33/100
# 60/60 - 1s - loss: 0.0107 - val_loss: 0.0127 - 879ms/epoch - 15ms/step
# Epoch 34/100
# 60/60 - 1s - loss: 0.0080 - val_loss: 0.0245 - 868ms/epoch - 14ms/step
# Epoch 35/100
# 60/60 - 1s - loss: 0.0163 - val_loss: 0.0167 - 879ms/epoch - 15ms/step
# Epoch 36/100
# 60/60 - 1s - loss: 0.0120 - val_loss: 0.0280 - 877ms/epoch - 15ms/step
# Epoch 37/100
# 60/60 - 1s - loss: 0.0238 - val_loss: 0.0270 - 874ms/epoch - 15ms/step
# Epoch 38/100
# 60/60 - 1s - loss: 0.0147 - val_loss: 0.0355 - 873ms/epoch - 15ms/step
# Epoch 39/100
# 60/60 - 1s - loss: 0.0250 - val_loss: 0.0296 - 876ms/epoch - 15ms/step
# Epoch 40/100
# 60/60 - 1s - loss: 0.0121 - val_loss: 0.0378 - 868ms/epoch - 14ms/step
# Epoch 41/100
# 60/60 - 1s - loss: 0.0174 - val_loss: 0.0194 - 889ms/epoch - 15ms/step
# Epoch 42/100
# 60/60 - 1s - loss: 0.0082 - val_loss: 0.0362 - 960ms/epoch - 16ms/step
# Epoch 43/100
# 60/60 - 1s - loss: 0.0119 - val_loss: 0.0137 - 947ms/epoch - 16ms/step
# Epoch 44/100
# 60/60 - 1s - loss: 0.0068 - val_loss: 0.0276 - 950ms/epoch - 16ms/step
# Epoch 45/100
# 60/60 - 1s - loss: 0.0112 - val_loss: 0.0139 - 928ms/epoch - 15ms/step
# Epoch 46/100
# 60/60 - 1s - loss: 0.0069 - val_loss: 0.0274 - 890ms/epoch - 15ms/step
# Epoch 47/100
# 60/60 - 1s - loss: 0.0123 - val_loss: 0.0134 - 876ms/epoch - 15ms/step
# Epoch 48/100
# 60/60 - 1s - loss: 0.0079 - val_loss: 0.0295 - 879ms/epoch - 15ms/step
# Epoch 49/100
# 60/60 - 1s - loss: 0.0151 - val_loss: 0.0144 - 866ms/epoch - 14ms/step
# Epoch 50/100
# 60/60 - 1s - loss: 0.0101 - val_loss: 0.0330 - 888ms/epoch - 15ms/step
# Epoch 51/100
# 60/60 - 1s - loss: 0.0187 - val_loss: 0.0178 - 878ms/epoch - 15ms/step
# Epoch 52/100
# 60/60 - 1s - loss: 0.0108 - val_loss: 0.0378 - 867ms/epoch - 14ms/step
# Epoch 53/100
# 60/60 - 1s - loss: 0.0175 - val_loss: 0.0178 - 880ms/epoch - 15ms/step
# Epoch 54/100
# 60/60 - 1s - loss: 0.0093 - val_loss: 0.0403 - 901ms/epoch - 15ms/step
# Epoch 55/100
# 60/60 - 1s - loss: 0.0144 - val_loss: 0.0146 - 906ms/epoch - 15ms/step
# Epoch 56/100
# 60/60 - 1s - loss: 0.0082 - val_loss: 0.0341 - 875ms/epoch - 15ms/step
# Epoch 57/100
# 60/60 - 1s - loss: 0.0136 - val_loss: 0.0143 - 877ms/epoch - 15ms/step
# Epoch 58/100
# 60/60 - 1s - loss: 0.0081 - val_loss: 0.0332 - 922ms/epoch - 15ms/step
# Epoch 59/100
# 60/60 - 1s - loss: 0.0141 - val_loss: 0.0136 - 921ms/epoch - 15ms/step
# Epoch 60/100
# 60/60 - 1s - loss: 0.0093 - val_loss: 0.0348 - 933ms/epoch - 16ms/step
# Epoch 61/100
# 60/60 - 1s - loss: 0.0180 - val_loss: 0.0160 - 951ms/epoch - 16ms/step
# Epoch 62/100
# 60/60 - 1s - loss: 0.0108 - val_loss: 0.0396 - 934ms/epoch - 16ms/step
# Epoch 63/100
# 60/60 - 1s - loss: 0.0186 - val_loss: 0.0177 - 870ms/epoch - 15ms/step
# Epoch 64/100
# 60/60 - 1s - loss: 0.0101 - val_loss: 0.0388 - 878ms/epoch - 15ms/step
# Epoch 65/100
# 60/60 - 1s - loss: 0.0169 - val_loss: 0.0157 - 902ms/epoch - 15ms/step
# Epoch 66/100
# 60/60 - 1s - loss: 0.0091 - val_loss: 0.0392 - 887ms/epoch - 15ms/step
# Epoch 67/100
# 60/60 - 1s - loss: 0.0142 - val_loss: 0.0142 - 860ms/epoch - 14ms/step
# Epoch 68/100
# 60/60 - 1s - loss: 0.0082 - val_loss: 0.0371 - 875ms/epoch - 15ms/step
# Epoch 69/100
# 60/60 - 1s - loss: 0.0136 - val_loss: 0.0136 - 884ms/epoch - 15ms/step
# Epoch 70/100
# 60/60 - 1s - loss: 0.0075 - val_loss: 0.0396 - 861ms/epoch - 14ms/step
# Epoch 71/100
# 60/60 - 1s - loss: 0.0126 - val_loss: 0.0128 - 864ms/epoch - 14ms/step
# Epoch 72/100
# 60/60 - 1s - loss: 0.0075 - val_loss: 0.0366 - 873ms/epoch - 15ms/step
# Epoch 73/100
# 60/60 - 1s - loss: 0.0137 - val_loss: 0.0130 - 888ms/epoch - 15ms/step
# Epoch 74/100
# 60/60 - 1s - loss: 0.0086 - val_loss: 0.0397 - 907ms/epoch - 15ms/step
# Epoch 75/100
# 60/60 - 1s - loss: 0.0147 - val_loss: 0.0136 - 959ms/epoch - 16ms/step
# Epoch 76/100
# 60/60 - 1s - loss: 0.0084 - val_loss: 0.0410 - 984ms/epoch - 16ms/step
# Epoch 77/100
# 60/60 - 1s - loss: 0.0145 - val_loss: 0.0132 - 1s/epoch - 17ms/step
# Epoch 78/100
# 60/60 - 1s - loss: 0.0084 - val_loss: 0.0419 - 1s/epoch - 17ms/step
# Epoch 79/100
# 60/60 - 1s - loss: 0.0145 - val_loss: 0.0127 - 1s/epoch - 17ms/step
# Epoch 80/100
# 60/60 - 1s - loss: 0.0088 - val_loss: 0.0422 - 934ms/epoch - 16ms/step
# Epoch 81/100
# 60/60 - 1s - loss: 0.0152 - val_loss: 0.0133 - 922ms/epoch - 15ms/step
# Epoch 82/100
# 60/60 - 1s - loss: 0.0094 - val_loss: 0.0408 - 936ms/epoch - 16ms/step
# Epoch 83/100
# 60/60 - 1s - loss: 0.0168 - val_loss: 0.0152 - 938ms/epoch - 16ms/step
# Epoch 84/100
# 60/60 - 1s - loss: 0.0094 - val_loss: 0.0430 - 943ms/epoch - 16ms/step
# Epoch 85/100
# 60/60 - 1s - loss: 0.0158 - val_loss: 0.0145 - 930ms/epoch - 16ms/step
# Epoch 86/100
# 60/60 - 1s - loss: 0.0086 - val_loss: 0.0435 - 941ms/epoch - 16ms/step
# Epoch 87/100
# 60/60 - 1s - loss: 0.0141 - val_loss: 0.0134 - 939ms/epoch - 16ms/step
# Epoch 88/100
# 60/60 - 1s - loss: 0.0082 - val_loss: 0.0410 - 940ms/epoch - 16ms/step
# Epoch 89/100
# 60/60 - 1s - loss: 0.0137 - val_loss: 0.0130 - 997ms/epoch - 17ms/step
# Epoch 90/100
# 60/60 - 1s - loss: 0.0076 - val_loss: 0.0422 - 953ms/epoch - 16ms/step
# Epoch 91/100
# 60/60 - 1s - loss: 0.0112 - val_loss: 0.0122 - 941ms/epoch - 16ms/step
# Epoch 92/100
# 60/60 - 1s - loss: 0.0070 - val_loss: 0.0378 - 963ms/epoch - 16ms/step
# Epoch 93/100
# 60/60 - 1s - loss: 0.0128 - val_loss: 0.0123 - 944ms/epoch - 16ms/step
# Epoch 94/100
# 60/60 - 1s - loss: 0.0083 - val_loss: 0.0423 - 951ms/epoch - 16ms/step
# Epoch 95/100
# 60/60 - 1s - loss: 0.0151 - val_loss: 0.0133 - 1s/epoch - 17ms/step
# Epoch 96/100
# 60/60 - 1s - loss: 0.0090 - val_loss: 0.0437 - 991ms/epoch - 17ms/step
# Epoch 97/100
# 60/60 - 1s - loss: 0.0169 - val_loss: 0.0138 - 996ms/epoch - 17ms/step
# Epoch 98/100
# 60/60 - 1s - loss: 0.0104 - val_loss: 0.0460 - 1s/epoch - 17ms/step
# Epoch 99/100
# 60/60 - 1s - loss: 0.0191 - val_loss: 0.0161 - 992ms/epoch - 17ms/step
# Epoch 100/100
# 60/60 - 1s - loss: 0.0097 - val_loss: 0.0509 - 930ms/epoch - 15ms/step
# 93/93 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 0s 3ms/step
#   Metric     Train      Test
# 0   RMSE  0.058723  0.223132
# 1    MAE  0.043623  0.202209
# 2    MSE  0.003448  0.049788
# 3     R2  0.993143  0.926717

# %%
# Initialize and train the LSTM model 3
lstm_3 = LSTM_Models(X_train, y_train, X_test, y_test, model3)
lstm_3.train_model(epochs=100, batch_size=50)
train_comparison_df,test_comparison_df = lstm_3.make_predictions(preprocessor.close_scaler)
lstm_3.plot_predictions(train_comparison_df, test_comparison_df)
results_df3 = lstm_3.evaluate_model(train_comparison_df, test_comparison_df)
print(results_df3)
# Out:
# Epoch 1/100
# 60/60 - 4s - loss: 0.1814 - val_loss: 0.5137 - 4s/epoch - 69ms/step
# Epoch 2/100
# 60/60 - 2s - loss: 0.0319 - val_loss: 0.0831 - 2s/epoch - 41ms/step
# Epoch 3/100
# 60/60 - 3s - loss: 0.0112 - val_loss: 0.0162 - 3s/epoch - 42ms/step
# Epoch 4/100
# 60/60 - 2s - loss: 0.0048 - val_loss: 0.0122 - 2s/epoch - 41ms/step
# Epoch 5/100
# 60/60 - 2s - loss: 0.0044 - val_loss: 0.0034 - 2s/epoch - 41ms/step
# Epoch 6/100
# 60/60 - 2s - loss: 0.0071 - val_loss: 0.0054 - 2s/epoch - 40ms/step
# Epoch 7/100
# 60/60 - 2s - loss: 0.0132 - val_loss: 0.0020 - 2s/epoch - 41ms/step
# Epoch 8/100
# 60/60 - 3s - loss: 0.0417 - val_loss: 0.0531 - 3s/epoch - 42ms/step
# Epoch 9/100
# 60/60 - 2s - loss: 0.0365 - val_loss: 0.0108 - 2s/epoch - 40ms/step
# Epoch 10/100
# 60/60 - 2s - loss: 0.0598 - val_loss: 0.1314 - 2s/epoch - 40ms/step
# Epoch 11/100
# 60/60 - 2s - loss: 0.0167 - val_loss: 0.0142 - 2s/epoch - 40ms/step
# Epoch 12/100
# 60/60 - 2s - loss: 0.0144 - val_loss: 0.0238 - 2s/epoch - 40ms/step
# Epoch 13/100
# 60/60 - 2s - loss: 0.0076 - val_loss: 0.0103 - 2s/epoch - 40ms/step
# Epoch 14/100
# 60/60 - 3s - loss: 0.0088 - val_loss: 0.0113 - 3s/epoch - 42ms/step
# Epoch 15/100
# 60/60 - 2s - loss: 0.0056 - val_loss: 0.0096 - 2s/epoch - 42ms/step
# Epoch 16/100
# 60/60 - 3s - loss: 0.0083 - val_loss: 0.0081 - 3s/epoch - 42ms/step
# Epoch 17/100
# 60/60 - 3s - loss: 0.0068 - val_loss: 0.0098 - 3s/epoch - 42ms/step
# Epoch 18/100
# 60/60 - 2s - loss: 0.0125 - val_loss: 0.0118 - 2s/epoch - 41ms/step
# Epoch 19/100
# 60/60 - 2s - loss: 0.0114 - val_loss: 0.0113 - 2s/epoch - 41ms/step
# Epoch 20/100
# 60/60 - 3s - loss: 0.0224 - val_loss: 0.0265 - 3s/epoch - 43ms/step
# Epoch 21/100
# 60/60 - 3s - loss: 0.0158 - val_loss: 0.0153 - 3s/epoch - 44ms/step
# Epoch 22/100
# 60/60 - 3s - loss: 0.0290 - val_loss: 0.0414 - 3s/epoch - 42ms/step
# Epoch 23/100
# 60/60 - 2s - loss: 0.0160 - val_loss: 0.0179 - 2s/epoch - 40ms/step
# Epoch 24/100
# 60/60 - 2s - loss: 0.0242 - val_loss: 0.0360 - 2s/epoch - 39ms/step
# Epoch 25/100
# 60/60 - 2s - loss: 0.0116 - val_loss: 0.0204 - 2s/epoch - 38ms/step
# Epoch 26/100
# 60/60 - 2s - loss: 0.0150 - val_loss: 0.0176 - 2s/epoch - 40ms/step
# Epoch 27/100
# 60/60 - 2s - loss: 0.0089 - val_loss: 0.0179 - 2s/epoch - 40ms/step
# Epoch 28/100
# 60/60 - 2s - loss: 0.0124 - val_loss: 0.0131 - 2s/epoch - 40ms/step
# Epoch 29/100
# 60/60 - 2s - loss: 0.0080 - val_loss: 0.0171 - 2s/epoch - 39ms/step
# Epoch 30/100
# 60/60 - 2s - loss: 0.0124 - val_loss: 0.0130 - 2s/epoch - 39ms/step
# Epoch 31/100
# 60/60 - 2s - loss: 0.0075 - val_loss: 0.0187 - 2s/epoch - 40ms/step
# Epoch 32/100
# 60/60 - 2s - loss: 0.0121 - val_loss: 0.0112 - 2s/epoch - 39ms/step
# Epoch 33/100
# 60/60 - 2s - loss: 0.0082 - val_loss: 0.0197 - 2s/epoch - 40ms/step
# Epoch 34/100
# 60/60 - 2s - loss: 0.0136 - val_loss: 0.0135 - 2s/epoch - 41ms/step
# Epoch 35/100
# 60/60 - 2s - loss: 0.0094 - val_loss: 0.0188 - 2s/epoch - 39ms/step
# Epoch 36/100
# 60/60 - 2s - loss: 0.0169 - val_loss: 0.0174 - 2s/epoch - 39ms/step
# Epoch 37/100
# 60/60 - 2s - loss: 0.0115 - val_loss: 0.0200 - 2s/epoch - 39ms/step
# Epoch 38/100
# 60/60 - 2s - loss: 0.0208 - val_loss: 0.0247 - 2s/epoch - 40ms/step
# Epoch 39/100
# 60/60 - 2s - loss: 0.0122 - val_loss: 0.0220 - 2s/epoch - 41ms/step
# Epoch 40/100
# 60/60 - 3s - loss: 0.0204 - val_loss: 0.0241 - 3s/epoch - 43ms/step
# Epoch 41/100
# 60/60 - 2s - loss: 0.0106 - val_loss: 0.0239 - 2s/epoch - 41ms/step
# Epoch 42/100
# 60/60 - 2s - loss: 0.0160 - val_loss: 0.0159 - 2s/epoch - 39ms/step
# Epoch 43/100
# 60/60 - 2s - loss: 0.0092 - val_loss: 0.0216 - 2s/epoch - 40ms/step
# Epoch 44/100
# 60/60 - 2s - loss: 0.0155 - val_loss: 0.0156 - 2s/epoch - 42ms/step
# Epoch 45/100
# 60/60 - 3s - loss: 0.0088 - val_loss: 0.0244 - 3s/epoch - 44ms/step
# Epoch 46/100
# 60/60 - 3s - loss: 0.0138 - val_loss: 0.0142 - 3s/epoch - 43ms/step
# Epoch 47/100
# 60/60 - 3s - loss: 0.0075 - val_loss: 0.0248 - 3s/epoch - 44ms/step
# Epoch 48/100
# 60/60 - 3s - loss: 0.0115 - val_loss: 0.0112 - 3s/epoch - 43ms/step
# Epoch 49/100
# 60/60 - 3s - loss: 0.0074 - val_loss: 0.0217 - 3s/epoch - 42ms/step
# Epoch 50/100
# 60/60 - 2s - loss: 0.0123 - val_loss: 0.0130 - 2s/epoch - 41ms/step
# Epoch 51/100
# 60/60 - 2s - loss: 0.0073 - val_loss: 0.0223 - 2s/epoch - 41ms/step
# Epoch 52/100
# 60/60 - 2s - loss: 0.0130 - val_loss: 0.0121 - 2s/epoch - 41ms/step
# Epoch 53/100
# 60/60 - 2s - loss: 0.0081 - val_loss: 0.0264 - 2s/epoch - 41ms/step
# Epoch 54/100
# 60/60 - 2s - loss: 0.0138 - val_loss: 0.0126 - 2s/epoch - 41ms/step
# Epoch 55/100
# 60/60 - 2s - loss: 0.0086 - val_loss: 0.0265 - 2s/epoch - 40ms/step
# Epoch 56/100
# 60/60 - 2s - loss: 0.0164 - val_loss: 0.0147 - 2s/epoch - 39ms/step
# Epoch 57/100
# 60/60 - 2s - loss: 0.0109 - val_loss: 0.0258 - 2s/epoch - 41ms/step
# Epoch 58/100
# 60/60 - 2s - loss: 0.0202 - val_loss: 0.0218 - 2s/epoch - 42ms/step
# Epoch 59/100
# 60/60 - 2s - loss: 0.0110 - val_loss: 0.0306 - 2s/epoch - 41ms/step
# Epoch 60/100
# 60/60 - 2s - loss: 0.0175 - val_loss: 0.0180 - 2s/epoch - 41ms/step
# Epoch 61/100
# 60/60 - 2s - loss: 0.0093 - val_loss: 0.0292 - 2s/epoch - 40ms/step
# Epoch 62/100
# 60/60 - 2s - loss: 0.0145 - val_loss: 0.0137 - 2s/epoch - 41ms/step
# Epoch 63/100
# 60/60 - 2s - loss: 0.0079 - val_loss: 0.0274 - 2s/epoch - 40ms/step
# Epoch 64/100
# 60/60 - 3s - loss: 0.0134 - val_loss: 0.0123 - 3s/epoch - 43ms/step
# Epoch 65/100
# 60/60 - 3s - loss: 0.0078 - val_loss: 0.0287 - 3s/epoch - 42ms/step
# Epoch 66/100
# 60/60 - 2s - loss: 0.0138 - val_loss: 0.0127 - 2s/epoch - 41ms/step
# Epoch 67/100
# 60/60 - 2s - loss: 0.0078 - val_loss: 0.0290 - 2s/epoch - 41ms/step
# Epoch 68/100
# 60/60 - 2s - loss: 0.0135 - val_loss: 0.0123 - 2s/epoch - 41ms/step
# Epoch 69/100
# 60/60 - 2s - loss: 0.0077 - val_loss: 0.0304 - 2s/epoch - 40ms/step
# Epoch 70/100
# 60/60 - 2s - loss: 0.0135 - val_loss: 0.0122 - 2s/epoch - 42ms/step
# Epoch 71/100
# 60/60 - 2s - loss: 0.0081 - val_loss: 0.0300 - 2s/epoch - 41ms/step
# Epoch 72/100
# 60/60 - 2s - loss: 0.0138 - val_loss: 0.0126 - 2s/epoch - 40ms/step
# Epoch 73/100
# 60/60 - 2s - loss: 0.0082 - val_loss: 0.0286 - 2s/epoch - 40ms/step
# Epoch 74/100
# 60/60 - 2s - loss: 0.0142 - val_loss: 0.0136 - 2s/epoch - 40ms/step
# Epoch 75/100
# 60/60 - 2s - loss: 0.0077 - val_loss: 0.0331 - 2s/epoch - 39ms/step
# Epoch 76/100
# 60/60 - 2s - loss: 0.0131 - val_loss: 0.0116 - 2s/epoch - 41ms/step
# Epoch 77/100
# 60/60 - 3s - loss: 0.0077 - val_loss: 0.0303 - 3s/epoch - 42ms/step
# Epoch 78/100
# 60/60 - 2s - loss: 0.0138 - val_loss: 0.0127 - 2s/epoch - 41ms/step
# Epoch 79/100
# 60/60 - 2s - loss: 0.0083 - val_loss: 0.0303 - 2s/epoch - 41ms/step
# Epoch 80/100
# 60/60 - 2s - loss: 0.0141 - val_loss: 0.0135 - 2s/epoch - 41ms/step
# Epoch 81/100
# 60/60 - 3s - loss: 0.0082 - val_loss: 0.0323 - 3s/epoch - 42ms/step
# Epoch 82/100
# 60/60 - 3s - loss: 0.0144 - val_loss: 0.0126 - 3s/epoch - 43ms/step
# Epoch 83/100
# 60/60 - 2s - loss: 0.0082 - val_loss: 0.0353 - 2s/epoch - 41ms/step
# Epoch 84/100
# 60/60 - 3s - loss: 0.0136 - val_loss: 0.0128 - 3s/epoch - 42ms/step
# Epoch 85/100
# 60/60 - 2s - loss: 0.0077 - val_loss: 0.0306 - 2s/epoch - 40ms/step
# Epoch 86/100
# 60/60 - 2s - loss: 0.0149 - val_loss: 0.0129 - 2s/epoch - 41ms/step
# Epoch 87/100
# 60/60 - 3s - loss: 0.0089 - val_loss: 0.0371 - 3s/epoch - 42ms/step
# Epoch 88/100
# 60/60 - 3s - loss: 0.0156 - val_loss: 0.0145 - 3s/epoch - 43ms/step
# Epoch 89/100
# 60/60 - 3s - loss: 0.0089 - val_loss: 0.0360 - 3s/epoch - 43ms/step
# Epoch 90/100
# 60/60 - 2s - loss: 0.0155 - val_loss: 0.0139 - 2s/epoch - 42ms/step
# Epoch 91/100
# 60/60 - 2s - loss: 0.0081 - val_loss: 0.0361 - 2s/epoch - 41ms/step
# Epoch 92/100
# 60/60 - 2s - loss: 0.0145 - val_loss: 0.0130 - 2s/epoch - 41ms/step
# Epoch 93/100
# 60/60 - 3s - loss: 0.0075 - val_loss: 0.0368 - 3s/epoch - 43ms/step
# Epoch 94/100
# 60/60 - 3s - loss: 0.0134 - val_loss: 0.0126 - 3s/epoch - 44ms/step
# Epoch 95/100
# 60/60 - 3s - loss: 0.0075 - val_loss: 0.0363 - 3s/epoch - 44ms/step
# Epoch 96/100
# 60/60 - 2s - loss: 0.0118 - val_loss: 0.0117 - 2s/epoch - 41ms/step
# Epoch 97/100
# 60/60 - 2s - loss: 0.0055 - val_loss: 0.0364 - 2s/epoch - 40ms/step
# Epoch 98/100
# 60/60 - 2s - loss: 0.0098 - val_loss: 0.0107 - 2s/epoch - 41ms/step
# Epoch 99/100
# 60/60 - 3s - loss: 0.0065 - val_loss: 0.0355 - 3s/epoch - 42ms/step
# Epoch 100/100
# 60/60 - 2s - loss: 0.0123 - val_loss: 0.0114 - 2s/epoch - 41ms/step
# 93/93 [==============================] - 1s 5ms/step
# 24/24 [==============================] - 0s 6ms/step
#   Metric     Train      Test
# 0   RMSE  0.060788  0.106748
# 1    MAE  0.034455  0.068651
# 2    MSE  0.003695  0.011395
# 3     R2  0.992652  0.983227

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Initialize and train the LSTM model 2
lstm_4 = LSTM_Models(X_train, y_train, X_test, y_test, model4)
lstm_4.train_model(epochs=100, batch_size=50)
train_comparison_df,test_comparison_df = lstm_4.make_predictions(preprocessor.close_scaler)
lstm_4.plot_predictions(train_comparison_df, test_comparison_df)
results_df4 = lstm_4.evaluate_model(train_comparison_df, test_comparison_df)
print(results_df4)
# Out:
# (2966, 1, 5) (2966,) (742, 1, 5) (742,)
# Epoch 1/100
# 60/60 - 7s - loss: 0.3097 - val_loss: 0.9022 - 7s/epoch - 108ms/step
# Epoch 2/100
# 60/60 - 3s - loss: 0.0870 - val_loss: 0.4098 - 3s/epoch - 48ms/step
# Epoch 3/100
# 60/60 - 3s - loss: 0.0280 - val_loss: 0.0882 - 3s/epoch - 48ms/step
# Epoch 4/100
# 60/60 - 3s - loss: 0.0135 - val_loss: 0.0320 - 3s/epoch - 48ms/step
# Epoch 5/100
# 60/60 - 3s - loss: 0.0060 - val_loss: 0.0189 - 3s/epoch - 47ms/step
# Epoch 6/100
# 60/60 - 3s - loss: 0.0037 - val_loss: 0.0099 - 3s/epoch - 45ms/step
# Epoch 7/100
# 60/60 - 3s - loss: 0.0025 - val_loss: 0.0069 - 3s/epoch - 49ms/step
# Epoch 8/100
# 60/60 - 3s - loss: 0.0022 - val_loss: 0.0058 - 3s/epoch - 50ms/step
# Epoch 9/100
# 60/60 - 3s - loss: 0.0024 - val_loss: 0.0054 - 3s/epoch - 54ms/step
# Epoch 10/100
# 60/60 - 3s - loss: 0.0023 - val_loss: 0.0052 - 3s/epoch - 53ms/step
# Epoch 11/100
# 60/60 - 3s - loss: 0.0022 - val_loss: 0.0053 - 3s/epoch - 46ms/step
# Epoch 12/100
# 60/60 - 3s - loss: 0.0021 - val_loss: 0.0050 - 3s/epoch - 45ms/step
# Epoch 13/100
# 60/60 - 3s - loss: 0.0024 - val_loss: 0.0053 - 3s/epoch - 45ms/step
# Epoch 14/100
# 60/60 - 3s - loss: 0.0023 - val_loss: 0.0047 - 3s/epoch - 50ms/step
# Epoch 15/100
# 60/60 - 3s - loss: 0.0035 - val_loss: 0.0062 - 3s/epoch - 50ms/step
# Epoch 16/100
# 60/60 - 3s - loss: 0.0074 - val_loss: 0.0058 - 3s/epoch - 49ms/step
# Epoch 17/100
# 60/60 - 3s - loss: 0.0459 - val_loss: 0.0277 - 3s/epoch - 47ms/step
# Epoch 18/100
# 60/60 - 3s - loss: 0.0838 - val_loss: 0.0145 - 3s/epoch - 46ms/step
# Epoch 19/100
# 60/60 - 3s - loss: 0.1536 - val_loss: 0.5199 - 3s/epoch - 46ms/step
# Epoch 20/100
# 60/60 - 3s - loss: 0.0121 - val_loss: 0.0133 - 3s/epoch - 48ms/step
# Epoch 21/100
# 60/60 - 3s - loss: 0.0034 - val_loss: 0.0151 - 3s/epoch - 45ms/step
# Epoch 22/100
# 60/60 - 3s - loss: 0.0037 - val_loss: 0.0093 - 3s/epoch - 45ms/step
# Epoch 23/100
# 60/60 - 3s - loss: 0.0026 - val_loss: 0.0108 - 3s/epoch - 49ms/step
# Epoch 24/100
# 60/60 - 3s - loss: 0.0033 - val_loss: 0.0085 - 3s/epoch - 48ms/step
# Epoch 25/100
# 60/60 - 3s - loss: 0.0026 - val_loss: 0.0107 - 3s/epoch - 49ms/step
# Epoch 26/100
# 60/60 - 3s - loss: 0.0034 - val_loss: 0.0083 - 3s/epoch - 47ms/step
# Epoch 27/100
# 60/60 - 3s - loss: 0.0026 - val_loss: 0.0110 - 3s/epoch - 45ms/step
# Epoch 28/100
# 60/60 - 3s - loss: 0.0039 - val_loss: 0.0080 - 3s/epoch - 47ms/step
# Epoch 29/100
# 60/60 - 3s - loss: 0.0029 - val_loss: 0.0118 - 3s/epoch - 46ms/step
# Epoch 30/100
# 60/60 - 3s - loss: 0.0052 - val_loss: 0.0075 - 3s/epoch - 51ms/step
# Epoch 31/100
# 60/60 - 3s - loss: 0.0050 - val_loss: 0.0104 - 3s/epoch - 51ms/step
# Epoch 32/100
# 60/60 - 3s - loss: 0.0132 - val_loss: 0.0089 - 3s/epoch - 46ms/step
# Epoch 33/100
# 60/60 - 3s - loss: 0.0156 - val_loss: 0.0114 - 3s/epoch - 47ms/step
# Epoch 34/100
# 60/60 - 3s - loss: 0.0425 - val_loss: 0.0471 - 3s/epoch - 45ms/step
# Epoch 35/100
# 60/60 - 3s - loss: 0.0272 - val_loss: 0.0191 - 3s/epoch - 46ms/step
# Epoch 36/100
# 60/60 - 3s - loss: 0.0508 - val_loss: 0.0744 - 3s/epoch - 47ms/step
# Epoch 37/100
# 60/60 - 3s - loss: 0.0177 - val_loss: 0.0220 - 3s/epoch - 45ms/step
# Epoch 38/100
# 60/60 - 3s - loss: 0.0228 - val_loss: 0.0224 - 3s/epoch - 46ms/step
# Epoch 39/100
# 60/60 - 3s - loss: 0.0104 - val_loss: 0.0206 - 3s/epoch - 47ms/step
# Epoch 40/100
# 60/60 - 3s - loss: 0.0150 - val_loss: 0.0125 - 3s/epoch - 47ms/step
# Epoch 41/100
# 60/60 - 3s - loss: 0.0074 - val_loss: 0.0191 - 3s/epoch - 47ms/step
# Epoch 42/100
# 60/60 - 3s - loss: 0.0116 - val_loss: 0.0099 - 3s/epoch - 48ms/step
# Epoch 43/100
# 60/60 - 3s - loss: 0.0067 - val_loss: 0.0192 - 3s/epoch - 48ms/step
# Epoch 44/100
# 60/60 - 3s - loss: 0.0117 - val_loss: 0.0096 - 3s/epoch - 50ms/step
# Epoch 45/100
# 60/60 - 3s - loss: 0.0078 - val_loss: 0.0164 - 3s/epoch - 48ms/step
# Epoch 46/100
# 60/60 - 3s - loss: 0.0151 - val_loss: 0.0113 - 3s/epoch - 49ms/step
# Epoch 47/100
# 60/60 - 3s - loss: 0.0108 - val_loss: 0.0185 - 3s/epoch - 48ms/step
# Epoch 48/100
# 60/60 - 3s - loss: 0.0219 - val_loss: 0.0164 - 3s/epoch - 46ms/step
# Epoch 49/100
# 60/60 - 3s - loss: 0.0143 - val_loss: 0.0214 - 3s/epoch - 45ms/step
# Epoch 50/100
# 60/60 - 3s - loss: 0.0278 - val_loss: 0.0230 - 3s/epoch - 44ms/step
# Epoch 51/100
# 60/60 - 3s - loss: 0.0148 - val_loss: 0.0242 - 3s/epoch - 48ms/step
# Epoch 52/100
# 60/60 - 3s - loss: 0.0251 - val_loss: 0.0206 - 3s/epoch - 48ms/step
# Epoch 53/100
# 60/60 - 3s - loss: 0.0125 - val_loss: 0.0236 - 3s/epoch - 47ms/step
# Epoch 54/100
# 60/60 - 3s - loss: 0.0206 - val_loss: 0.0158 - 3s/epoch - 47ms/step
# Epoch 55/100
# 60/60 - 3s - loss: 0.0100 - val_loss: 0.0255 - 3s/epoch - 46ms/step
# Epoch 56/100
# 60/60 - 3s - loss: 0.0159 - val_loss: 0.0116 - 3s/epoch - 46ms/step
# Epoch 57/100
# 60/60 - 3s - loss: 0.0082 - val_loss: 0.0227 - 3s/epoch - 47ms/step
# Epoch 58/100
# 60/60 - 3s - loss: 0.0139 - val_loss: 0.0108 - 3s/epoch - 49ms/step
# Epoch 59/100
# 60/60 - 3s - loss: 0.0080 - val_loss: 0.0212 - 3s/epoch - 48ms/step
# Epoch 60/100
# 60/60 - 3s - loss: 0.0152 - val_loss: 0.0107 - 3s/epoch - 47ms/step
# Epoch 61/100
# 60/60 - 3s - loss: 0.0099 - val_loss: 0.0219 - 3s/epoch - 45ms/step
# Epoch 62/100
# 60/60 - 3s - loss: 0.0203 - val_loss: 0.0147 - 3s/epoch - 46ms/step
# Epoch 63/100
# 60/60 - 3s - loss: 0.0116 - val_loss: 0.0246 - 3s/epoch - 47ms/step
# Epoch 64/100
# 60/60 - 3s - loss: 0.0222 - val_loss: 0.0167 - 3s/epoch - 45ms/step
# Epoch 65/100
# 60/60 - 3s - loss: 0.0118 - val_loss: 0.0251 - 3s/epoch - 44ms/step
# Epoch 66/100
# 60/60 - 3s - loss: 0.0210 - val_loss: 0.0156 - 3s/epoch - 45ms/step
# Epoch 67/100
# 60/60 - 3s - loss: 0.0110 - val_loss: 0.0268 - 3s/epoch - 45ms/step
# Epoch 68/100
# 60/60 - 3s - loss: 0.0186 - val_loss: 0.0132 - 3s/epoch - 47ms/step
# Epoch 69/100
# 60/60 - 3s - loss: 0.0096 - val_loss: 0.0264 - 3s/epoch - 45ms/step
# Epoch 70/100
# 60/60 - 3s - loss: 0.0165 - val_loss: 0.0120 - 3s/epoch - 44ms/step
# Epoch 71/100
# 60/60 - 3s - loss: 0.0088 - val_loss: 0.0262 - 3s/epoch - 45ms/step
# Epoch 72/100
# 60/60 - 3s - loss: 0.0154 - val_loss: 0.0113 - 3s/epoch - 44ms/step
# Epoch 73/100
# 60/60 - 3s - loss: 0.0088 - val_loss: 0.0260 - 3s/epoch - 46ms/step
# Epoch 74/100
# 60/60 - 3s - loss: 0.0167 - val_loss: 0.0115 - 3s/epoch - 47ms/step
# Epoch 75/100
# 60/60 - 3s - loss: 0.0099 - val_loss: 0.0274 - 3s/epoch - 45ms/step
# Epoch 76/100
# 60/60 - 3s - loss: 0.0191 - val_loss: 0.0138 - 3s/epoch - 45ms/step
# Epoch 77/100
# 60/60 - 3s - loss: 0.0100 - val_loss: 0.0296 - 3s/epoch - 45ms/step
# Epoch 78/100
# 60/60 - 3s - loss: 0.0187 - val_loss: 0.0127 - 3s/epoch - 44ms/step
# Epoch 79/100
# 60/60 - 3s - loss: 0.0102 - val_loss: 0.0281 - 3s/epoch - 46ms/step
# Epoch 80/100
# 60/60 - 3s - loss: 0.0185 - val_loss: 0.0138 - 3s/epoch - 48ms/step
# Epoch 81/100
# 60/60 - 3s - loss: 0.0104 - val_loss: 0.0273 - 3s/epoch - 47ms/step
# Epoch 82/100
# 60/60 - 3s - loss: 0.0203 - val_loss: 0.0140 - 3s/epoch - 46ms/step
# Epoch 83/100
# 60/60 - 3s - loss: 0.0110 - val_loss: 0.0306 - 3s/epoch - 47ms/step
# Epoch 84/100
# 60/60 - 3s - loss: 0.0193 - val_loss: 0.0137 - 3s/epoch - 48ms/step
# Epoch 85/100
# 60/60 - 3s - loss: 0.0104 - val_loss: 0.0310 - 3s/epoch - 48ms/step
# Epoch 86/100
# 60/60 - 3s - loss: 0.0189 - val_loss: 0.0134 - 3s/epoch - 46ms/step
# Epoch 87/100
# 60/60 - 3s - loss: 0.0093 - val_loss: 0.0315 - 3s/epoch - 45ms/step
# Epoch 88/100
# 60/60 - 3s - loss: 0.0165 - val_loss: 0.0118 - 3s/epoch - 45ms/step
# Epoch 89/100
# 60/60 - 3s - loss: 0.0087 - val_loss: 0.0315 - 3s/epoch - 45ms/step
# Epoch 90/100
# 60/60 - 3s - loss: 0.0155 - val_loss: 0.0114 - 3s/epoch - 47ms/step
# Epoch 91/100
# 60/60 - 3s - loss: 0.0085 - val_loss: 0.0287 - 3s/epoch - 46ms/step
# Epoch 92/100
# 60/60 - 3s - loss: 0.0170 - val_loss: 0.0114 - 3s/epoch - 44ms/step
# Epoch 93/100
# 60/60 - 3s - loss: 0.0096 - val_loss: 0.0301 - 3s/epoch - 44ms/step
# Epoch 94/100
# 60/60 - 3s - loss: 0.0191 - val_loss: 0.0128 - 3s/epoch - 46ms/step
# Epoch 95/100
# 60/60 - 3s - loss: 0.0101 - val_loss: 0.0308 - 3s/epoch - 47ms/step
# Epoch 96/100
# 60/60 - 3s - loss: 0.0191 - val_loss: 0.0131 - 3s/epoch - 48ms/step
# Epoch 97/100
# 60/60 - 3s - loss: 0.0097 - val_loss: 0.0344 - 3s/epoch - 45ms/step
# Epoch 98/100
# 60/60 - 3s - loss: 0.0175 - val_loss: 0.0115 - 3s/epoch - 44ms/step
# Epoch 99/100
# 60/60 - 3s - loss: 0.0096 - val_loss: 0.0321 - 3s/epoch - 44ms/step
# Epoch 100/100
# 60/60 - 3s - loss: 0.0186 - val_loss: 0.0122 - 3s/epoch - 45ms/step
# 93/93 [==============================] - 1s 6ms/step
# 24/24 [==============================] - 0s 6ms/step
#   Metric     Train      Test
# 0   RMSE  0.065914  0.111936
# 1    MAE  0.032302  0.064864
# 2    MSE  0.004345  0.012530
# 3     R2  0.991361  0.981557

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# Define a function that creates a model, required for KerasClassifier
def create_model(dropout_rate=0.0, dense_units=1, optimizer='adam'):
    print(f"Model run, dropout_rate = {dropout_rate}, dense_units = {dense_units}, optimizer = {optimizer}")
    model = Sequential()
    model.add(LSTM(120, activation="tanh", input_shape=(1, 5)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_units))
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    return model

# Wrap our Keras model in an estimator compatible with scikit_learn
model = KerasRegressor(build_fn=create_model, verbose=0)

param_grid = {
    'batch_size': [50, 100, 256, 512],
    'epochs': [100],
    'dropout_rate': [0.1, 0.15, 0.2, 0.3],
    'dense_units': [1],
    'optimizer': ['Adam']
}

# %%
# Create Grid Search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1, scoring='r2')
grid_result = grid.fit(X_train, y_train)

# Report Results
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print(f"Means: {mean}, Stdev: {stdev} with: {param}")
# Out:
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026F0917EB90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026F080E4700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.3, dense_units = 1, optimizer = Adam
# Model run, dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Best: 0.9438865928572907 using {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.15, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.8752058552460916, Stdev: 0.23105406765177058 with: {'batch_size': 50, 'dense_units': 1, 'dropout_rate': 0.1, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.8821240842083313, Stdev: 0.15532412919735647 with: {'batch_size': 50, 'dense_units': 1, 'dropout_rate': 0.15, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.43052523949245075, Stdev: 0.7522463959459212 with: {'batch_size': 50, 'dense_units': 1, 'dropout_rate': 0.2, 'epochs': 100, 'optimizer': 'Adam'}
# Means: -0.33229312342697936, Stdev: 2.2522690644268395 with: {'batch_size': 50, 'dense_units': 1, 'dropout_rate': 0.3, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.7587632027911397, Stdev: 0.37921225287094856 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.1, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.9438865928572907, Stdev: 0.062198850775648046 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.15, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.8850591829312693, Stdev: 0.1391511556891448 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.2, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.754104443542924, Stdev: 0.42113874212013697 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.3, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.7149341900952345, Stdev: 0.45483301881294896 with: {'batch_size': 256, 'dense_units': 1, 'dropout_rate': 0.1, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.9382613902683584, Stdev: 0.05581593515328507 with: {'batch_size': 256, 'dense_units': 1, 'dropout_rate': 0.15, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.8913250956231977, Stdev: 0.12136613623520523 with: {'batch_size': 256, 'dense_units': 1, 'dropout_rate': 0.2, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.8278864045502339, Stdev: 0.1777225804050905 with: {'batch_size': 256, 'dense_units': 1, 'dropout_rate': 0.3, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.24777332299906424, Stdev: 0.8394024807047821 with: {'batch_size': 512, 'dense_units': 1, 'dropout_rate': 0.1, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.4453075800637626, Stdev: 0.569367190720336 with: {'batch_size': 512, 'dense_units': 1, 'dropout_rate': 0.15, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.14516257114882727, Stdev: 1.1522028427260922 with: {'batch_size': 512, 'dense_units': 1, 'dropout_rate': 0.2, 'epochs': 100, 'optimizer': 'Adam'}
# Means: 0.08226272849427585, Stdev: 1.2145533541660323 with: {'batch_size': 512, 'dense_units': 1, 'dropout_rate': 0.3, 'epochs': 100, 'optimizer': 'Adam'}

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# Define a function that creates a model, required for KerasClassifier
def create_model(neurons=128, dropout_rate=0.0, dense_units=1, optimizer='adam'):
    print(f"Model run, neurons = {neurons}, dropout_rate = {dropout_rate}, dense_units = {dense_units}, optimizer = {optimizer}")
    model = Sequential()
    model.add(LSTM(neurons, activation="tanh", input_shape=(1, 5)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_units))
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    return model

# Wrap our Keras model in an estimator compatible with scikit_learn
model = KerasRegressor(build_fn=create_model, verbose=0)

param_grid = {
    'neurons': [64, 128, 256, 512],
    'batch_size': [100],
    'epochs': [100],
    'dropout_rate': [0.1, 0.15, 0.2],
    'dense_units': [1],
    'optimizer': ['Adam']
}

# %%
# Create Grid Search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1, scoring='r2')
grid_result = grid.fit(X_train, y_train)

# Report Results
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print(f"Means: {mean}, Stdev: {stdev} with: {param}")
# Out:
# Model run, neurons = 64 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.15, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 64 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 128 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 512 dropout_rate = 0.2, dense_units = 1, optimizer = Adam
# Model run, neurons = 256 dropout_rate = 0.1, dense_units = 1, optimizer = Adam
# Best: 0.9811009740199278 using {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.1, 'epochs': 100, 'neurons': 256, 'optimizer': 'Adam'}
# Means: 0.919355041073403, Stdev: 0.07560130413582926 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.1, 'epochs': 100, 'neurons': 64, 'optimizer': 'Adam'}
# Means: 0.9094174770032657, Stdev: 0.12384062145768848 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.1, 'epochs': 100, 'neurons': 128, 'optimizer': 'Adam'}
# Means: 0.9811009740199278, Stdev: 0.02186406512637543 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.1, 'epochs': 100, 'neurons': 256, 'optimizer': 'Adam'}
# Means: 0.9541203774027099, Stdev: 0.0794926984556794 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.1, 'epochs': 100, 'neurons': 512, 'optimizer': 'Adam'}
# Means: 0.80954497212153, Stdev: 0.2901933455555738 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.15, 'epochs': 100, 'neurons': 64, 'optimizer': 'Adam'}
# Means: 0.9603597995771501, Stdev: 0.045525979275448686 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.15, 'epochs': 100, 'neurons': 128, 'optimizer': 'Adam'}
# Means: 0.9259752948216322, Stdev: 0.1289636929449622 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.15, 'epochs': 100, 'neurons': 256, 'optimizer': 'Adam'}
# Means: 0.9701809786453316, Stdev: 0.04197416581213289 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.15, 'epochs': 100, 'neurons': 512, 'optimizer': 'Adam'}
# Means: 0.732819702807724, Stdev: 0.43868986637180674 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.2, 'epochs': 100, 'neurons': 64, 'optimizer': 'Adam'}
# Means: 0.9548419218364683, Stdev: 0.038914795398413124 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.2, 'epochs': 100, 'neurons': 128, 'optimizer': 'Adam'}
# Means: 0.9394912237687525, Stdev: 0.10130241748772839 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.2, 'epochs': 100, 'neurons': 256, 'optimizer': 'Adam'}
# Means: 0.9370256238431601, Stdev: 0.1166246684886158 with: {'batch_size': 100, 'dense_units': 1, 'dropout_rate': 0.2, 'epochs': 100, 'neurons': 512, 'optimizer': 'Adam'}
